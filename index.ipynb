# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
df = pd.read_csv('WorldCupMatches.csv')
df.head(7)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930.0  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
# 6     Yugoslavia              4.0              0.0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
# 5                     9249.0                   1.0                   0.0
# 6                    18306.0                   0.0                   0.0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
# 5         LANGENUS Jean (BEL)    201.0   1095.0                CHI
# 6       WARNKEN Alberto (CHI)    201.0   1092.0                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
df.tail(3)
# Out:
#       Year Datetime Stage Stadium City Home Team Name  Home Team Goals  \
# 4569   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4570   NaN      NaN   NaN     NaN  NaN            NaN              NaN
# 4571   NaN      NaN   NaN     NaN  NaN            NaN              NaN
#
#       Away Team Goals Away Team Name Win conditions  Attendance  \
# 4569              NaN            NaN            NaN         NaN
# 4570              NaN            NaN            NaN         NaN
# 4571              NaN            NaN            NaN         NaN
#
#       Half-time Home Goals  Half-time Away Goals Referee Assistant 1  \
# 4569                   NaN                   NaN     NaN         NaN
# 4570                   NaN                   NaN     NaN         NaN
# 4571                   NaN                   NaN     NaN         NaN
#
#      Assistant 2  RoundID  MatchID Home Team Initials Away Team Initials
# 4569         NaN      NaN      NaN                NaN                NaN
# 4570         NaN      NaN      NaN                NaN                NaN
# 4571         NaN      NaN      NaN                NaN                NaN

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
# Year                    852 non-null float64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null float64
# Away Team Goals         852 non-null float64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null float64
# Half-time Away Goals    852 non-null float64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null float64
# MatchID                 852 non-null float64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(8), object(12)
# memory usage: 714.5+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
df.shape
# Out:
# (4572, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
df.iloc[3:6]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
# 5                     9249.0                   1.0                   0.0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3    201.0   1098.0                ROU                PER
# 4    201.0   1085.0                ARG                FRA
# 5    201.0   1095.0                CHI                MEX

# %% [markdown]
# Now, print all the info from game 5-8, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
df.loc[5:8, ["Home Team Name", "Away Team Name"]]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
df.loc[(df['Year'] == 1950) & (df['Stage'] == "Group 3")]
# Out:
#       Year              Datetime    Stage           Stadium        City  \
# 56  1950.0  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950.0  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950.0  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden              3.0              2.0          Italy
# 61         Sweden              2.0              2.0       Paraguay
# 65          Italy              2.0              0.0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                   2.0                   1.0
# 61                     7903.0                   2.0                   1.0
# 65                    25811.0                   1.0                   0.0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56    208.0   1219.0                SWE                ITA
# 61    208.0   1228.0                SWE                PAR
# 65    208.0   1218.0                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance colum for the Group 3 games

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
df.loc[(df['Year'] == 1950) & (df['Stage'] == "Group 3"), ['Attendance']]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
nl_homes = df.loc[df['Home Team Name'] == 'Netherlands']
print(len(nl_homes))
# Out:
# 32

# %% [markdown]
# How many games were playes by the Netherlands in total?

# %%
nl_away = df.loc[df['Away Team Name'] == 'Netherlands']
print(len(nl_away))
# Out:
# 22

# %%
print(len(nl_homes) + len(nl_away))
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
                # first condition: year  # second condition: either home or away
US_2014 = df.loc[(df['Year'] == 2014) & ((df['Home Team Name'] == 'USA') | (df['Away Team Name'] == 'USA'))]
print(len(US_2014))
# Out:
# 5

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %%
worldcup_1986 = df.loc[df['Year'] == 1986]
home = list(worldcup_1986['Home Team Name'].unique())
away = list(worldcup_1986['Away Team Name'].unique())

# %%
countries_1986 = set(home + away)
print(len(countries_1986))
# Out:
# 24

# %% [markdown]
# In the world cup history, how many matches had more than 5 goals in total?

# %%
df['Total_Goals'] = df['Home Team Goals'] + df['Away Team Goals']
len(df[df.Total_Goals >= 5])
# Out:
# 147

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %%
df['Half_Time_Goals'] = df['Half-time Home Goals'] + df['Half-time Away Goals']

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
df.loc[df["Home Team Name"].str.contains('Korea', na=False), ["Home Team Name"]]
# Out:
#      Home Team Name
# 179       Korea DPR
# 187       Korea DPR
# 374  Korea Republic
# 386  Korea Republic
# 434  Korea Republic
# 444  Korea Republic
# 480  Korea Republic
# 524  Korea Republic
# 593  Korea Republic
# 609  Korea Republic
# 635  Korea Republic
# 642  Korea Republic
# 655  Korea Republic
# 710  Korea Republic
# 753       Korea DPR
# 802  Korea Republic
# 818  Korea Republic

# %% [markdown]
# Imagine that for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
df.loc[df["Home Team Name"] == "Korea DPR", ["Home Team Name"]] = "Korea"
df.loc[df["Home Team Name"] == "Korea Republic", ["Home Team Name"]] = "Korea"
df.loc[df["Away Team Name"] == "Korea DPR", ["Away Team Name"]] = "Korea"
df.loc[df["Away Team Name"] == "Korea Republic", ["Away Team Name"]] = "Korea"
df.loc[df["Home Team Initials"] == "KOR", ["Home Team Initials"]] = "NSK"
df.loc[df["Home Team Initials"] == "KOR", ["Home Team Initials"]] = "NSK"
df.loc[df["Away Team Initials"] == "PRK", ["Away Team Initials"]] = "NSK"
df.loc[df["Away Team Initials"] == "PRK", ["Away Team Initials"]] = "NSK"

# %% [markdown]
# Make sure to verify your answer!

# %%
df.loc[df["Home Team Name"].str.contains('Korea', na=False)].head()
# Out:
#        Year              Datetime    Stage                         Stadium  \
# 179  1966.0  15 Jul 1966 - 19:30   Group 4                   Ayresome Park
# 187  1966.0  19 Jul 1966 - 19:30   Group 4                   Ayresome Park
# 374  1986.0  05 Jun 1986 - 16:00   Group A  Estadio Ol�mpico Universitario
# 386  1986.0  10 Jun 1986 - 12:00   Group A                      Cuauhtemoc
# 434  1990.0  17 Jun 1990 - 21:00   Group E                     Dacia Arena
#
#                City Home Team Name  Home Team Goals  Away Team Goals  \
# 179  Middlesbrough           Korea              1.0              1.0
# 187  Middlesbrough           Korea              1.0              0.0
# 374    Mexico City           Korea              1.0              1.0
# 386         Puebla           Korea              2.0              3.0
# 434          Udine           Korea              1.0              3.0
#
#     Away Team Name Win conditions       ...        Half-time Away Goals  \
# 179          Chile                      ...                         1.0
# 187          Italy                      ...                         0.0
# 374       Bulgaria                      ...                         1.0
# 386          Italy                      ...                         1.0
# 434          Spain                      ...                         1.0
#
#                             Referee             Assistant 1  \
# 179        KANDIL Aly Hussein (EGY)  CRAWFORD William (SCO)
# 187           SCHWINTE Pierre (FRA)        ADAIR John (NIR)
# 374   AL SHANAR Fallaj Khuzam (KSA)         IGNA Ioan (ROU)
# 386               SOCHA David (USA)     URREA Joaquin (MEX)
# 434  JACOME GUERRERO Elias V. (ECU)   MAGNI Pierluigi (ITA)
#
#                Assistant 2 RoundID MatchID  Home Team Initials  \
# 179       FINNEY Jim (ENG)   238.0  1609.0                 PRK
# 187      TAYLOR John (ENG)   238.0  1679.0                 PRK
# 374   BUTENKO Valeri (RUS)   308.0   460.0                 NSK
# 386  AL SHARIF Jamal (SYR)   308.0   643.0                 NSK
# 434     LOUSTAU Juan (ARG)   322.0   175.0                 NSK
#
#      Away Team Initials Total_Goals Half_Time_Goals
# 179                 CHI         2.0             1.0
# 187                 ITA         1.0             1.0
# 374                 BUL         2.0             1.0
# 386                 ITA         5.0             1.0
# 434                 ESP         4.0             2.0
#
# [5 rows x 22 columns]

# %%
df.loc[df["Away Team Name"].str.contains('Korea', na=False)].head()
# Out:
#        Year              Datetime           Stage  \
# 80   1954.0  17 Jun 1954 - 18:00          Group 2
# 88   1954.0  20 Jun 1954 - 17:00          Group 2
# 171  1966.0  12 Jul 1966 - 19:30          Group 4
# 195  1966.0  23 Jul 1966 - 15:00   Quarter-finals
# 364  1986.0  02 Jun 1986 - 12:00          Group A
#
#                             Stadium            City Home Team Name  \
# 80                         Hardturm         Zurich         Hungary
# 88                       Charmilles         Geneva          Turkey
# 171                   Ayresome Park  Middlesbrough    Soviet Union
# 195                   Goodison Park      Liverpool        Portugal
# 364  Estadio Ol�mpico Universitario    Mexico City       Argentina
#
#      Home Team Goals  Away Team Goals Away Team Name Win conditions  \
# 80               9.0              0.0          Korea
# 88               7.0              0.0          Korea
# 171              3.0              0.0          Korea
# 195              5.0              3.0          Korea
# 364              3.0              1.0          Korea
#
#           ...        Half-time Away Goals                           Referee  \
# 80        ...                         0.0            VINCENTI Raymond (FRA)
# 88        ...                         0.0              MARINO Esteban (URU)
# 171       ...                         0.0            GARDEAZABAL Juan (ESP)
# 195       ...                         3.0          ASHKENAZI Menachem (ISR)
# 364       ...                         0.0  SANCHEZ ARMINIO Victoriano (ESP)
#
#                     Assistant 1               Assistant 2 RoundID MatchID  \
# 80      VON GUNTER Albert (SUI)        STEINER Carl (AUT)   211.0  1294.0
# 88     ORLANDINI Vincenzo (ITA)  SCHONHOLZER Ernest (SUI)   211.0  1304.0
# 171    KANDIL Aly Hussein (EGY)    DIENST Gottfried (SUI)   238.0  1710.0
# 195           GALBA Karol (TCH)     SCHWINTE Pierre (FRA)   239.0  1702.0
# 364  GONZALEZ ROA Gabriel (PAR)  DIAZ PALACIO Jesus (COL)   308.0   395.0
#
#      Home Team Initials  Away Team Initials Total_Goals Half_Time_Goals
# 80                  HUN                 KOR         9.0             4.0
# 88                  TUR                 KOR         7.0             4.0
# 171                 URS                 NSK         3.0             2.0
# 195                 POR                 NSK         8.0             5.0
# 364                 ARG                 KOR         4.0             2.0
#
# [5 rows x 22 columns]
